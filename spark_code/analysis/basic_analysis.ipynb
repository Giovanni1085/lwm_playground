# %%
# IMPORTS

import pandas as pd
import numpy as np
import matplotlib 
import matplotlib.pyplot as plt
import seaborn as sns

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# Set style for figures
sns.set_style("whitegrid")
sns.set(font_scale = 1.5)

# %%
df = pd.read_csv("df_test.csv")

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'file_name', 'character_count', 'predicted_word_accuracy',
#        'suspicious_character_count', 'word_count', 'suspicious_word_count',
#        'width', 'height', 'xdpi', 'ydpi'],
#       dtype='object')

# %%
df.drop('Unnamed: 0', inplace=True, axis=1)

# %%
df.head()
# Out:
#                                            file_name  character_count  \
# 0  wasbs://fmp-batch-1@giovanniplayground.blob.co...            65017
# 1  wasbs://fmp-batch-1@giovanniplayground.blob.co...            44408
# 2  wasbs://fmp-batch-1@giovanniplayground.blob.co...            53212
# 3  wasbs://fmp-batch-1@giovanniplayground.blob.co...            36775
# 4  wasbs://fmp-batch-1@giovanniplayground.blob.co...            49852
#
#    predicted_word_accuracy  suspicious_character_count  word_count  \
# 0                     73.8                        8843       11749
# 1                     73.8                        5013        7086
# 2                     76.9                        5101        9712
# 3                     84.8                        1340        6436
# 4                     79.1                        4015        8105
#
#    suspicious_word_count  width  height  xdpi  ydpi
# 0                   4617   5034    5929   300   300
# ...

# %%
sns.distplot(df.predicted_word_accuracy)

# %%
plt.figure(1)
sns.distplot(df.word_count, label="All")
sns.distplot(df.suspicious_word_count, label="Suspicious")
plt.xlabel("Word count")
plt.legend()

# %%
plt.figure(2)
sns.distplot(np.nan_to_num(((df.word_count.values - df.suspicious_word_count.values)/df.word_count.values)*100), label="Fine")
sns.distplot(np.nan_to_num((df.suspicious_word_count.values/df.word_count.values)*100), label="Suspicious")
plt.xlabel("Word proportion")
plt.legend()
# Out:
# /Users/gcolavizza/anaconda3/envs/ds36/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
#
# /Users/gcolavizza/anaconda3/envs/ds36/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in true_divide
#
# /Users/gcolavizza/anaconda3/envs/ds36/lib/python3.6/site-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/gcolavizza/anaconda3/envs/ds36/lib/python3.6/site-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
